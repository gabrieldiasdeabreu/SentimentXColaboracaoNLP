# %% [markdown]
# # Usando SentiStrength
#
# ## Api do sentistrength

# %%
'''requer plotly, pandas, requests, re e json'''
import plotly
import requests
import re
import json as Json
import pandas as pd
import time
# import matplotlib.pyplot as plt
# import numpy as np

import plotly.plotly as py
print(plotly.__version__)  # version >1.9.4 required
import plotly.graph_objs as go
from plotly.graph_objs import Scatter, Layout
# Out:
# 3.7.0

# %%
def arrumaQuery(query):
    ''' funcao auxiliar para arrumar a query'''
    return query.replace(' ', '+').replace('\n', '+')

# %%
def get(url):
    try:
        return requests.get(url)
    except Exception:
        # sleep for a bit in case that helps
        time.sleep(1)
        # try again
        return get(url)

# %%
def retornaSentimentoComSentiStrength(query):
    '''
    funcao que avalia os sentimentos utilizando 
    o SentiStrength retornando os 
    resultados posivitos e negativos
    '''
    BaseUrl =  "http://sentistrength.wlv.ac.uk"

    DOMAIN = "AutoDetect";
    SUBMIT = "Detect+Sentiment+in+Domain"
    
    # monta URL
    url = BaseUrl+'/results.php?domain='+DOMAIN+'&submit='+SUBMIT+'&text='+arrumaQuery(query)
    
#     print(url)
    #requisita
    r = get(url = url)
    
    # usa regex para capturar nota
    notaExpr = re.compile(r'has positive strength <b>.*</b> and negative strength <b>.*</b>')
    textoFiltrado = re.findall(notaExpr, str(r.content))
    pegaNotaPositiva = str(textoFiltrado).split('<b>')[1].split('</b>')[0]
    pegaNotaNegativa = str(textoFiltrado).split('<b>')[2].split('</b>')[0]
    
    return {'NotaPositiva':int(pegaNotaPositiva), 'NotaNegativa':int(pegaNotaNegativa)}

# %%
# retornaSentimentoComSentiStrength('this is a horrible idea')

# %%
# pd.DataFrame(columns=['autor', 'data', 'mensagem', 'NotaPos', 'NotaNeg'])
json = None
with open('exemplo.json', 'r') as arq:
    json = arq.read()
#     for commit in json.loads(arq.read()):
# #         print(commit)
#         nota = retornaSentimentoComSentiStrength(commit['mensagem'])
# #         print('autor:', commit['autor'])
# #         print('data:', commit['data'])
# #         print('mensagem:', commit['mensagem'])
# #         print('sentiment', nota)
#         dados.append([
#             commit['autor'],
#             commit['data'],
#             commit['mensagem'],
#             nota['NotaPositiva'],
#             nota['NotaNegativa']            
#         ])

# %%
def converteJsonParaDataFrame(json):
    '''
    Recebe um Json represantando um commit com os campos 
    commit['autor'],
    commit['data'],
    commit['mensagem'] e retorna um DataFrame para análise
    '''
    i = 1
    dados = []
    for commit in Json.loads(json):
        print('Analisando a mensagem #'+str(i)+' :')
#         print(commit['mensagem'])
#         print('de : '+commit['autor'] + ' em '+ commit['data'])
#         print('mensagem : ' + str(i))
        nota = retornaSentimentoComSentiStrength(commit['mensagem'])
        dados.append([
            commit['autor'],
            commit['data'],
            commit['mensagem'],
            nota['NotaPositiva'],
            nota['NotaNegativa']            
        ])
        i+=1
    dados = pd.DataFrame(dados, columns=['autor', 'data', 'mensagem', 'NotaPos', 'NotaNeg'])
    dados.data = pd.to_datetime(dados.data)
    dados = dados.set_index('data')
    
    return dados

# %%
def plotaGraficosSentimentoPorUsuario(dados):    
    # itera por cada usuário identificado no Json
    for grupo in dados.groupby('autor'):
        url = plotly.offline.plot({
            'data':[
                go.Bar(
                    x=grupo[1].index, # assign x as the dataframe column 'x'
                    y=grupo[1]['NotaPos'],
                    name='Positive Sentiment'
                ),
                go.Bar(
                    x=grupo[1].index, # assign x as the dataframe column 'x'
                    y=grupo[1]['NotaNeg'],
                    name='Negative Sentiment'
                )
            ],
            "layout": Layout(
                title=grupo[0],
                xaxis=dict(title='Commit Data'),
                yaxis=dict(title='Sentiment Polarity'),

            )
        }, filename='graphs/SentimentoDoColaborador_'+grupo[0]+'.html')

# %%
# dados.sort_index()[['NotaPos','NotaNeg', 'mensagem', 'autor']].to_csv('saida_Codigo.csv')
# dados.describe().to_csv('analiseSaida.csv')

# %%
def plotaGraficosSentimentoProjeto(dados, nomeProjeto):    
    # itera por cada usuário identificado no Json
#     for grupo in dados.groupby('autor'):
    url = plotly.offline.plot({
        'data':[
            go.Scatter(
                x=dados.index, # assign x as the dataframe column 'x'
                y=dados['NotaPos'],
                name='Positive Sentiment'
            ),
            go.Scatter(
                x=dados.index, # assign x as the dataframe column 'x'
                y=dados['NotaNeg'],
                name='Negative Sentiment'
            )
        ],
        "layout": Layout(
            title='Projeto: '+nomeProjeto,
            xaxis=dict(title='Commit Data'),
            yaxis=dict(title='Sentiment Polarity'),

        )
    }, filename='graphs/sentimentoDoProjetoAoLongoDoTempo.html')

# %%
dados = converteJsonParaDataFrame(json)
# Out:
# Analisando a mensagem #1 :
# Analisando a mensagem #2 :
# Analisando a mensagem #3 :
# Analisando a mensagem #4 :
# Analisando a mensagem #5 :
# Analisando a mensagem #6 :
# Analisando a mensagem #7 :
# Analisando a mensagem #8 :
# Analisando a mensagem #9 :
# Analisando a mensagem #10 :
# Analisando a mensagem #11 :
# Analisando a mensagem #12 :
# Analisando a mensagem #13 :
# Analisando a mensagem #14 :
# Analisando a mensagem #15 :
# Analisando a mensagem #16 :
# Analisando a mensagem #17 :
# Analisando a mensagem #18 :
# Analisando a mensagem #19 :
# Analisando a mensagem #20 :
# Analisando a mensagem #21 :
# Analisando a mensagem #22 :
# Analisando a mensagem #23 :
# Analisando a mensagem #24 :
# Analisando a mensagem #25 :
# Analisando a mensagem #26 :
# Analisando a mensagem #27 :
# Analisando a mensagem #28 :
# Analisando a mensagem #29 :
# Analisando a mensagem #30 :

# %%
dados
# Out:
#                                       autor  \
# data
# 2019-06-06 13:34:33            Edward Loper
# 2019-06-06 12:59:43  A. Unique TensorFlower
# 2019-06-06 12:59:19   TensorFlower Gardener
# 2019-06-06 11:46:59  A. Unique TensorFlower
# 2019-06-06 10:47:24            Tiezhen WANG
# 2019-06-06 10:41:22  A. Unique TensorFlower
# 2019-06-06 10:04:40          Sergei Lebedev
# 2019-06-06 09:17:31  A. Unique TensorFlower
# 2019-06-06 09:09:32  A. Unique TensorFlower
# 2019-06-06 09:13:29   TensorFlower Gardener
# 2019-06-06 08:22:32  A. Unique TensorFlower
# 2019-06-06 07:53:20  A. Unique TensorFlower
# 2019-06-06 06:25:28   TensorFlower Gardener
# 2019-06-06 05:37:57   TensorFlower Gardener
# 2019-06-06 02:54:52              Renjie Liu
# 2019-06-06 01:55:48          Mihai Maruseac
# 2019-06-06 00:11:18              Jared Duke
# 2019-06-06 00:05:50  A. Unique TensorFlower
# 2019-06-05 23:37:33  A. Unique TensorFlower
# 2019-06-05 23:29:45        George Karpenkov
# 2019-06-05 23:18:34              Sanjoy Das
# 2019-06-05 22:29:34  A. Unique TensorFlower
# 2019-06-05 22:06:48               Yanan Cao
# 2019-06-05 21:52:09               Yanan Cao
# 2019-06-05 21:46:05            Katherine Wu
# 2019-06-05 21:45:28  A. Unique TensorFlower
# 2019-06-05 21:18:16             Karim Nosir
# 2019-06-05 21:13:24          Haoliang Zhang
# 2019-06-05 21:10:19               Yanan Cao
# 2019-06-05 21:02:34  A. Unique TensorFlower
#
#                                                               mensagem  \
# data
# 2019-06-06 13:34:33  Do not override the tf.gather docs with gen_ar...
# 2019-06-06 12:59:43  Apply 'buildozer fix moveLicensesAndDistribs m...
# 2019-06-06 12:59:19  Merge pull request #29193 from chosungmann:fix...
# 2019-06-06 11:46:59  Put the dynamic libraries into the platlib (pl...
# 2019-06-06 10:47:24  Initialize context using memset\n\nPiperOrigin...
# 2019-06-06 10:41:22  [TF:XLA] Handle predicates for matrix diagonal...
# 2019-06-06 10:04:40  Migrated LSTMBlock* and GRUCell* ops from cont...
# 2019-06-06 09:17:31  Small LLVM build file change (table_gen -> tab...
# 2019-06-06 09:09:32  [TF:XLA] Handle bitcasts between different bit...
# 2019-06-06 09:13:29  Merge pull request #29366 from georgepaw:custo...
# 2019-06-06 08:22:32  [TF:XLA] Broadcast Labels or Logits for Softma...
# 2019-06-06 07:53:20  Add Pfor converter for SelectV2.\n\nPiperOrigi...
# 2019-06-06 06:25:28  Merge pull request #29045 from Intel-tensorflo...
# 2019-06-06 05:37:57  Merge pull request #29326 from imransalam:patc...
# 2019-06-06 02:54:52  Give out warning if model has place holder but...
# 2019-06-06 01:55:48    Internal change\n\nPiperOrigin-RevId: 251765499
# 2019-06-06 00:11:18    Internal change\n\nPiperOrigin-RevId: 251750813
# 2019-06-06 00:05:50  Expose step container name in TraceMes for ops...
# 2019-06-05 23:37:33  Bring up first working camera demo for micro v...
# 2019-06-05 23:29:45  Do not attempt to start a subprocess on Window...
# 2019-06-05 23:18:34  [TF:XLA] Bump open source abseil revision to 6...
# 2019-06-05 22:29:34                n/a\n\nPiperOrigin-RevId: 251731764
# 2019-06-05 22:06:48    Internal change\n\nPiperOrigin-RevId: 251727442
# 2019-06-05 21:52:09  Add support for XlaCompileOnDemandOp to analyz...
# 2019-06-05 21:46:05  Set SavedModel as default format for model.sav...
# 2019-06-05 21:45:28  Near comparison now works for non-fp types. Ca...
# 2019-06-05 21:18:16  Parameterize the mlir_coverage_test and add mo...
# 2019-06-05 21:13:24  Support ANEURALNETWORKS_TENSOR_BOOL8 in NNAPI ...
# 2019-06-05 21:10:19    Internal change\n\nPiperOrigin-RevId: 251715294
# 2019-06-05 21:02:34  Special case 1D resizes and no-op resizes.\n\n...
#
#                      NotaPos  NotaNeg
# data
# 2019-06-06 13:34:33        1       -1
# 2019-06-06 12:59:43        1       -1
# 2019-06-06 12:59:19        1       -1
# 2019-06-06 11:46:59        2       -2
# 2019-06-06 10:47:24        1       -1
# 2019-06-06 10:41:22        1       -1
# 2019-06-06 10:04:40        1       -1
# 2019-06-06 09:17:31        1       -1
# 2019-06-06 09:09:32        1       -1
# 2019-06-06 09:13:29        1       -1
# 2019-06-06 08:22:32        1       -1
# 2019-06-06 07:53:20        1       -1
# 2019-06-06 06:25:28        1       -1
# 2019-06-06 05:37:57        1       -1
# 2019-06-06 02:54:52        1       -1
# 2019-06-06 01:55:48        1       -1
# 2019-06-06 00:11:18        1       -1
# 2019-06-06 00:05:50        1       -2
# 2019-06-05 23:37:33        1       -1
# 2019-06-05 23:29:45        1       -1
# 2019-06-05 23:18:34        1       -1
# 2019-06-05 22:29:34        1       -1
# 2019-06-05 22:06:48        1       -1
# 2019-06-05 21:52:09        2       -1
# 2019-06-05 21:46:05        2       -2
# 2019-06-05 21:45:28        1       -3
# 2019-06-05 21:18:16        2       -1
# 2019-06-05 21:13:24        2       -2
# 2019-06-05 21:10:19        1       -1
# 2019-06-05 21:02:34        2       -1

# %%
plotaGraficosSentimentoProjeto(dados, 'tensorflow')

# %%
plotaGraficosSentimentoPorUsuario(dados)

# %%
# pandas>=0.23.4
